# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd 

import tqdm
from pathlib import Path
from collections import defaultdict, Counter

# %%
DATA_ROOT = Path('../input/kakr-3rd-copy/')
train_csv = pd.read_csv('../input/kakr-3rd-copy/train.csv')

# %%
def make_folds(n_folds: int) -> pd.DataFrame:
    df = pd.read_csv(DATA_ROOT / 'train.csv', engine='python')

    cls_counts = Counter([classes for classes in df['class']])
    fold_cls_counts = defaultdict()
    
    for class_index in cls_counts.keys():
        fold_cls_counts[class_index] = np.zeros(n_folds, dtype=np.int)   
        
    df['fold'] = -1    
    pbar = tqdm.tqdm(total=len(df))

    def get_fold(row):
        class_index = row['class']
        counts = fold_cls_counts[class_index]
        
        fold = np.argmin(counts)
        counts[fold] += 1
        fold_cls_counts[class_index] = counts
        row['fold']=fold
        
        pbar.update()
        return row
        
    df = df.apply(get_fold, axis=1)
    return df

# %%
df = make_folds(n_folds=5)
print("df:")
print(df)
df.to_csv('folds2.csv', index=None)
# Out:
#   0%|          | 0/9990 [00:00<?, ?it/s]
#
#   3%|▎         | 299/9990 [00:00<00:03, 2988.36it/s]
# fold_cls_counts
# defaultdict(None, {108: array([0, 0, 0, 0, 0]), 71: array([0, 0, 0, 0, 0]), 76: array([0, 0, 0, 0, 0]), 188: array([0, 0, 0, 0, 0]), 44: array([0, 0, 0, 0, 0]), 29: array([0, 0, 0, 0, 0]), 113: array([0, 0, 0, 0, 0]), 66: array([0, 0, 0, 0, 0]), 97: array([0, 0, 0, 0, 0]), 177: array([0, 0, 0, 0, 0]), 142: array([0, 0, 0, 0, 0]), 10: array([0, 0, 0, 0, 0]), 127: array([0, 0, 0, 0, 0]), 64: array([0, 0, 0, 0, 0]), 93: array([0, 0, 0, 0, 0]), 39: array([0, 0, 0, 0, 0]), 196: array([0, 0, 0, 0, 0]), 173: array([0, 0, 0, 0, 0]), 135: array([0, 0, 0, 0, 0]), 152: array([0, 0, 0, 0, 0]), 178: array([0, 0, 0, 0, 0]), 134: array([0, 0, 0, 0, 0]), 131: array([0, 0, 0, 0, 0]), 50: array([0, 0, 0, 0, 0]), 28: array([0, 0, 0, 0, 0]), 65: array([0, 0, 0, 0, 0]), 21: array([0, 0, 0, 0, 0]), 30: array([0, 0, 0, 0, 0]), 91: array([0, 0, 0, 0, 0]), 164: array([0, 0, 0, 0, 0]), 4: array([0, 0, 0, 0, 0]), 5: array([0, 0, 0, 0, 0]), 180: array([0, 0, 0, 0, 0]), 193: array([0, 0, 0, 0, 0]), 165: array([0, 0, 0, 0, 0]), 105: array([0, 0, 0, 0, 0]), 8: array([0, 0, 0, 0, 0]), 63: array([0, 0, 0, 0, 0]), 133: array([0, 0, 0, 0, 0]), 56: array([0, 0, 0, 0, 0]), 103: array([0, 0, 0, 0, 0]), 20: array([0, 0, 0, 0, 0]), 96: array([0, 0, 0, 0, 0]), 141: array([0, 0, 0, 0, 0]), 14: array([0, 0, 0, 0, 0]), 13: array([0, 0, 0, 0, 0]), 84: array([0, 0, 0, 0, 0]), 99: array([0, 0, 0, 0, 0]), 190: array([0, 0, 0, 0, 0]), 157: array([0, 0, 0, 0, 0]), 59: array([0, 0, 0, 0, 0]), 1: array([0, 0, 0, 0, 0]), 147: array([0, 0, 0, 0, 0]), 182: array([0, 0, 0, 0, 0]), 172: array([0, 0, 0, 0, 0]), 171: array([0, 0, 0, 0, 0]), 155: array([0, 0, 0, 0, 0]), 69: array([0, 0, 0, 0, 0]), 40: array([0, 0, 0, 0, 0]), 60: array([0, 0, 0, 0, 0]), 75: array([0, 0, 0, 0, 0]), 81: array([0, 0, 0, 0, 0]), 18: array([0, 0, 0, 0, 0]), 54: array([0, 0, 0, 0, 0]), 183: array([0, 0, 0, 0, 0]), 73: array([0, 0, 0, 0, 0]), 49: array([0, 0, 0, 0, 0]), 48: array([0, 0, 0, 0, 0]), 154: array([0, 0, 0, 0, 0]), 80: array([0, 0, 0, 0, 0]), 98: array([0, 0, 0, 0, 0]), 167: array([0, 0, 0, 0, 0]), 168: array([0, 0, 0, 0, 0]), 52: array([0, 0, 0, 0, 0]), 88: array([0, 0, 0, 0, 0]), 100: array([0, 0, 0, 0, 0]), 118: array([0, 0, 0, 0, 0]), 161: array([0, 0, 0, 0, 0]), 104: array([0, 0, 0, 0, 0]), 132: array([0, 0, 0, 0, 0]), 38: array([0, 0, 0, 0, 0]), 126: array([0, 0, 0, 0, 0]), 26: array([0, 0, 0, 0, 0]), 124: array([0, 0, 0, 0, 0]), 148: array([0, 0, 0, 0, 0]), 191: array([0, 0, 0, 0, 0]), 174: array([0, 0, 0, 0, 0]), 153: array([0, 0, 0, 0, 0]), 122: array([0, 0, 0, 0, 0]), 138: array([0, 0, 0, 0, 0]), 160: array([0, 0, 0, 0, 0]), 162: array([0, 0, 0, 0, 0]), 15: array([0, 0, 0, 0, 0]), 139: array([0, 0, 0, 0, 0]), 43: array([0, 0, 0, 0, 0]), 45: array([0, 0, 0, 0, 0]), 179: array([0, 0, 0, 0, 0]), 192: array([0, 0, 0, 0, 0]), 111: array([0, 0, 0, 0, 0]), 146: array([0, 0, 0, 0, 0]), 95: array([0, 0, 0, 0, 0]), 87: array([0, 0, 0, 0, 0]), 130: array([0, 0, 0, 0, 0]), 32: array([0, 0, 0, 0, 0]), 24: array([0, 0, 0, 0, 0]), 184: array([0, 0, 0, 0, 0]), 79: array([0, 0, 0, 0, 0]), 58: array([0, 0, 0, 0, 0]), 41: array([0, 0, 0, 0, 0]), 156: array([0, 0, 0, 0, 0]), 150: array([0, 0, 0, 0, 0]), 17: array([0, 0, 0, 0, 0]), 128: array([0, 0, 0, 0, 0]), 90: array([0, 0, 0, 0, 0]), 42: array([0, 0, 0, 0, 0]), 136: array([0, 0, 0, 0, 0]), 47: array([0, 0, 0, 0, 0]), 82: array([0, 0, 0, 0, 0]), 36: array([0, 0, 0, 0, 0]), 51: array([0, 0, 0, 0, 0]), 119: array([0, 0, 0, 0, 0]), 101: array([0, 0, 0, 0, 0]), 159: array([0, 0, 0, 0, 0]), 194: array([0, 0, 0, 0, 0]), 195: array([0, 0, 0, 0, 0]), 120: array([0, 0, 0, 0, 0]), 62: array([0, 0, 0, 0, 0]), 129: array([0, 0, 0, 0, 0]), 9: array([0, 0, 0, 0, 0]), 57: array([0, 0, 0, 0, 0]), 67: array([0, 0, 0, 0, 0]), 35: array([0, 0, 0, 0, 0]), 140: array([0, 0, 0, 0, 0]), 19: array([0, 0, 0, 0, 0]), 34: array([0, 0, 0, 0, 0]), 77: array([0, 0, 0, 0, 0]), 3: array([0, 0, 0, 0, 0]), 89: array([0, 0, 0, 0, 0]), 55: array([0, 0, 0, 0, 0]), 123: array([0, 0, 0, 0, 0]),  ...
#              img_file  bbox_x1  bbox_y1  bbox_x2  bbox_y2  class
# 0     train_00001.jpg        1       80      641      461    108
# 1     train_00002.jpg       57       53      293      236     71
# 2     train_00003.jpg       35       42      227      160     76
# 3     train_00004.jpg       10       21      254      165    188
# 4     train_00005.jpg        1       67      772      573     44
# ...               ...      ...      ...      ...      ...    ...
# 9985  train_09986.jpg       61      206      996      621    122
# 9986  train_09987.jpg      127       45      665      412    176
# 9987  train_09988.jpg       23       13      231      112    151
# 9988  train_09989.jpg       24      103      561      387     59
# 9989  train_09990.jpg       52      122      750      429     44
#
# [9990 rows x 6 columns]
#              img_file  bbox_x1  bbox_y1  bbox_x2  bbox_y2  class  fold
# 0     train_00001.jpg        1       80      641      461    108    -1
# 1     train_00002.jpg       57       53      293      236     71    -1
# 2     train_00003.jpg       35       42      227      160     76    -1
# 3     train_00004.jpg       10       21      254      165    188    -1
# 4     train_00005.jpg        1       67      772      573     44    -1
# ...               ...      ...      ...      ...      ...    ...   ...
# 9985  train_09986.jpg       61      206      996      621    122    -1
# 9986  train_09987.jpg      127       45      665      412    176    -1
# 9987  train_09988.jpg       23       13      231      112    151    -1
# 9988  train_09989.jpg       24      103      561      387     59    -1
# 9989  train_09990.jpg       52      122      750      429     44    -1
#
# [9990 rows x 7 columns]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
#   5%|▌         | 545/9990 [00:00<00:03, 2806.55it/s]
#
#   7%|▋         | 743/9990 [00:00<00:03, 2492.64it/s]
# counts
# [1 0 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [0 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [0 0 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [0 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [0 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
#   9%|▉         | 924/9990 [00:00<00:04, 2237.18it/s]
#
#  11%|█         | 1109/9990 [00:00<00:04, 2104.07it/s]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [0 0 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 0 0 0]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 0 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 0 0]
# counts
#  13%|█▎        | 1336/9990 [00:00<00:04, 2078.61it/s]
#
#  15%|█▌        | 1544/9990 [00:00<00:04, 2068.67it/s]
# [1 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [3 3 3 3 3]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 1 1 1]
# counts
# [4 3 3 3 3]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [3 3 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 0 0 0]
# counts
# [2 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [3 3 3 3 3]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [3 3 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 3 2]
# counts
# [1 1 1 1 0]
# counts
# [3 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [1 1 0 0 0]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [4 4 3 3 3]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 2 2]
#  17%|█▋        | 1731/9990 [00:00<00:04, 1986.48it/s]
#
#  19%|█▉        | 1919/9990 [00:00<00:04, 1952.90it/s]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [4 3 3 3 3]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 2 2]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [1 1 1 0 0]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 3 3]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 0]
# counts
# [1 1 0 0 0]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [3 3 3 3 3]
# counts
# [3 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 2 2]
# counts
# [1 1 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [4 4 4 3 3]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 3 2]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 2 2 2 2]
# counts
# [3 3 3 3 2]
# counts
# [2 2 1 1 1]
# counts
# [4 3 3 3 3]
# counts
# [1 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 0]
# counts
# [3 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [3 3 3 3 3]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 3 3]
# counts
# [2 2 2 2 1]
# counts
# [4 4 3 3 3]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 3 3]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 2 2]
# counts
# [2 2 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [3 3 2 2 2]
# counts
# [1 1 1 0 0]
# counts
# [1 1 1 1 0]
# counts
# [2 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 3 3]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 3 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [4 4 4 4 3]
# counts
# [3 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 3 2]
# counts
# [2 1 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 1 1 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 3 3]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 3 2]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 2 2 2 2]
#  21%|██        | 2106/9990 [00:01<00:04, 1815.02it/s]
#
#  23%|██▎       | 2296/9990 [00:01<00:04, 1838.35it/s]
# counts
# [4 4 4 4 4]
# counts
# [2 2 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [2 1 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [4 3 3 3 3]
# counts
# [4 3 3 3 3]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 3 3]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 1]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 3 3]
# counts
# [4 4 3 3 3]
# counts
# [3 3 3 3 3]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 3 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [4 3 3 3 3]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 3 3]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [4 4 4 3 3]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 3 3]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 1]
# counts
# [2 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [3 2 2 2 2]
# counts
# [3 3 3 3 3]
# counts
# [2 2 1 1 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 3 2]
# counts
# [3 3 3 3 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 1 1 1]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [4 3 3 3 3]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 3 2 2 2]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [1 1 1 1 1]
# counts
# [2 2 2 1 1]
# counts
# [5 4 4 4 4]
# counts
# [2 2 2 1 1]
# counts
# [5 5 4 4 4]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [3 3 3 3 2]
# counts
# [4 3 3 3 3]
# counts
# [3 3 3 3 2]
# counts
# [3 3 2 2 2]
# counts
# [3 3 2 2 2]
# counts
# [3 3 3 2 2]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 2 1]
# counts
# [2 2 1 1 1]
# counts
# [3 3 3 3 2]
# counts
# [3 3 3 3 3]
# counts
# [2 2 2 1 1]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 2 2 2]
# counts
# [2 2 2 2 1]
# counts
# [3 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 1 1 1 1]
# counts
# [2 2 2 2 1]
# counts
# [3 3 3 2 2]
# counts
# [3 3 3 3 3]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 2 2]
# counts
# [2 2 2 1 1]
# counts
# [3 3 3 2 2]
# counts
# ...
# counts
# [9 9 9 9 8]
# counts
# [10  9  9  9  9]
# counts
# [9 9 8 8 8]
# counts
# [10 10  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10  9  9]
# counts
# [11 11 11 10 10]
# counts
# [9 9 9 8 8]
# counts
# [11 11 11 11 10]
# counts
# [8 8 8 8 8]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [9 9 9 9 9]
# counts
# [12 11 11 11 11]
# counts
# [9 9 9 9 8]
# counts
# [10 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 8 8]
# counts
# [10 10 10 10 10]
# counts
# [7 7 7 7 7]
# counts
# [9 8 8 8 8]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 9 9]
# counts
# [9 9 8 8 8]
# counts
# [11 11 11 11 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10  9]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [10 10 10 10  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10  9  9  9]
# counts
# [9 8 8 8 8]
# counts
# [9 9 9 9 8]
# counts
# [11 10 10 10 10]
# counts
# [7 7 7 6 6]
# counts
# [9 9 9 9 8]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [6 6 6 5 5]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10  9  9  9]
# counts
# [9 9 9 9 9]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 9 8]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10  9  9]
# counts
# [11 11 11 10 10]
# counts
# [9 9 9 9 8]
# counts
# [10  9  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 11 11]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [8 8 7 7 7]
# counts
# [11 11 11 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [9 8 8 8 8]
# counts
# [8 7 7 7 7]
# counts
# [9 9 9 9 8]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 8 8]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 8 8]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 8 8]
# counts
# [9 9 9 9 8]
# counts
# [8 8 7 7 7]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 9 9]
# counts
# [7 7 7 7 6]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [9 9 8 8 8]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 9 9]
# counts
# [9 9 9 9 9]
# counts
# [11 11 11 10 10]
# counts
# [10  9  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [10 10  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [9 9 8 8 8]
# counts
# [10 10 10 10 10]
# counts
# [7 7 7 7 7]
# counts
# [9 9 9 9 8]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [10 10 10 10  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [8 8 8 8 8]
# counts
# [10 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [11 11 11 11 11]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10  9  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [10 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [8 8 8 7 7]
# counts
# [11 11 10 10 10]
# counts
# [12 11 11 11 11]
# counts
# [11 10 10 10 10]
# counts
# [9 8 8 8 8]
# counts
# [9 8 8 8 8]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 10 10]
# counts
# [9 9 8 8 8]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 11 10]
# counts
# [8 7 7 7 7]
# counts
# [9 8 8 8 8]
# counts
# [11 11 11 10 10]
# counts
# [9 9 9 9 9]
# counts
# [11 11 11 11 11]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 8 8]
# counts
# [9 9 8 8 8]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10 10]
# counts
# [9 9 9 9 9]
# counts
# [9 9 9 8 8]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [9 9 9 8 8]
# counts
# [10 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [10  9  9  9  9]
# counts
# [9 9 9 8 8]
# counts
# [10 10 10  9  9]
# counts
# [11 10 10 10 10]
# counts
# [8 8 8 7 7]
# counts
# [10  9  9  9  9]
# counts
# [9 9 9 9 9]
# counts
# [9 9 9 9 9]
# counts
# [8 8 8 8 7]
# counts
# [11 11 11 10 10]
# counts
# [9 8 8 8 8]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10  9  9]
# counts
# [11 10 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [8 8 8 8 8]
# counts
# [10 10 10 10  9]
# counts
# [11 11 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10  9  9]
# counts
# [8 8 8 7 7]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [16 16 16 16 15]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10  9  9  9  9]
# counts
# [9 9 9 9 9]
# counts
# [10 10  9  9  9]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 9 8]
# counts
# [10 10 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10 10]
# counts
# [16 16 16 16 16]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10  9  9  9  9]
# counts
# [9 9 9 9 9]
# counts
# [9 9 9 9 8]
# counts
# [9 9 9 8 8]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10  9]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10  9  9]
# counts
# [11 10 10 10 10]
# counts
# [9 9 9 9 9]
# counts
# [11 11 11 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [9 8 8 8 8]
# counts
# [11 11 11 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [9 8 8 8 8]
# counts
# [10 10 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 11]
# counts
# [10  9  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [9 9 8 8 8]
# counts
# [9 9 9 9 8]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 11 10]
# counts
# [10  9  9  9  9]
# counts
# [11 11 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 10 10 10 10]
# counts
# [8 8 7 7 7]
# counts
# [11 11 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [9 8 8 8 8]
# counts
# [9 9 9 9 8]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 9 9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 9 9]
# counts
# [9 8 8 8 8]
# counts
# [10 10  9  9  9]
# counts
# [12 12 11 11 11]
# counts
# [10 10  9  9  9]
# counts
# [12 11 11 11 11]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 11 10]
# counts
# [8 8 8 8 7]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 8 8]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 11 11 11 10]
# counts
# [11 11 11 11 11]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [7 7 7 6 6]
# counts
# [10 10  9  9  9]
# counts
# [11 11 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [9 9 9 9 9]
# counts
# [10  9  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [9 9 8 8 8]
# counts
# [11 11 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 8 8]
# counts
# [10 10 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [10 10  9  9  9]
# counts
# [11 11 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [12 12 11 11 11]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10 10  9]
# counts
# [12 11 11 11 11]
# counts
# [9 9 9 9 8]
# counts
# [11 11 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 8 8]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 11 11 11 11]
# counts
# [11 11 10 10 10]
# counts
# [8 8 7 7 7]
# counts
# [10  9  9  9  9]
# counts
# [7 7 7 7 6]
# counts
# [11 11 10 10 10]
# counts
# [10 10  9  9  9]
#  98%|█████████▊| 9769/9990 [00:05<00:00, 1925.89it/s]
#
# 100%|█████████▉| 9965/9990 [00:05<00:00, 1922.76it/s]
# counts
# [10 10 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [10 10  9  9  9]
# counts
# [10 10  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [12 12 11 11 11]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 11 11]
# counts
# [8 8 8 7 7]
# counts
# [11 11 11 11 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10  9]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [7 7 7 7 7]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 11]
# counts
# [10  9  9  9  9]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [10 10  9  9  9]
# counts
# [9 9 9 8 8]
# counts
# [9 9 8 8 8]
# counts
# [9 9 8 8 8]
# counts
# [10 10  9  9  9]
# counts
# [9 9 8 8 8]
# counts
# [11 11 11 11 10]
# counts
# [11 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [9 9 8 8 8]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [12 12 12 11 11]
# counts
# [11 11 11 11 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 9 9]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [12 12 12 12 11]
# counts
# [9 9 9 9 9]
# counts
# [9 9 9 8 8]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 11 11]
# counts
# [11 11 11 11 11]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [11 11 11 11 11]
# counts
# [11 11 11 11 11]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 8 8]
# counts
# [11 11 11 11 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [11 11 11 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 11 10 10 10]
# counts
# [8 8 8 8 8]
# counts
# [10 10  9  9  9]
# counts
# [10 10  9  9  9]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10  9  9]
# counts
# [11 10 10 10 10]
# counts
# [12 11 11 11 11]
# counts
# [10 10 10  9  9]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [10 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 11 11]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [11 11 11 10 10]
# counts
# [9 9 9 9 8]
# counts
# [11 11 11 11 10]
# counts
# [12 11 11 11 11]
# counts
# [10 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [8 8 8 8 7]
# counts
# [11 11 10 10 10]
# counts
# [12 12 12 11 11]
# counts
# [11 10 10 10 10]
# counts
# [9 9 9 8 8]
# counts
# [11 11 11 10 10]
# counts
# [10  9  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [11 11 11 11 10]
# counts
# [17 16 16 16 16]
# counts
# [10 10 10  9  9]
# counts
# [11 11 11 10 10]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 11 10]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [8 8 8 8 8]
# counts
# [10 10  9  9  9]
# counts
# [12 11 11 11 11]
# counts
# [9 9 8 8 8]
# counts
# [11 11 11 11 11]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10 10  9]
# counts
# [9 9 9 9 9]
# counts
# [10 10  9  9  9]
# counts
# [10 10  9  9  9]
# counts
# [10  9  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10 10 10  9  9]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10  9  9]
# counts
# [10 10  9  9  9]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [10 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 11 10]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10 10]
# counts
# [8 8 8 8 7]
# counts
# [17 17 16 16 16]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 8 8]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 9 8]
# counts
# [12 12 12 11 11]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 11 11]
# counts
# [10 10 10  9  9]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 11 10]
# counts
# [11 11 11 10 10]
# counts
# [9 9 9 9 9]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 11 11]
# counts
# [10 10 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 11 10]
# counts
# [11 11 10 10 10]
# counts
# [11 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [11 11 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 11 10]
# counts
# [11 10 10 10 10]
# counts
# [11 11 11 11 11]
# counts
# [11 11 11 11 11]
# counts
# [11 10 10 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [9 9 9 9 8]
# counts
# [11 11 11 11 11]
# counts
# [12 11 11 11 11]
# counts
# [10 10  9  9  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [11 11 10 10 10]
# counts
# [12 11 11 11 11]
# counts
# [7 7 7 7 7]
# counts
# [11 11 11 11 10]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10  9  9]
# counts
# [6 6 6 6 5]
# counts
# [9 9 9 9 8]
# counts
# [10 10 10 10 10]
# counts
# [9 8 8 8 8]
# counts
# [10 10 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 10 10 10]
# counts
# [11 11 11 10 10]
# counts
# [8 7 7 7 7]
# counts
# [10 10 10 10 10]
# counts
# [10 10  9  9  9]
# counts
# [11 11 10 10 10]
# counts
# [10 10 10 10  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 10 10]
# counts
# [10 10 10  9  9]
# counts
# [9 9 9 9 8]
# counts
# [11 11 10 10 10]
# counts
# [12 11 11 11 11]
# counts
# [11 11 11 10 10]
# counts
# [10  9  9  9  9]
# counts
# [10 10 10  9  9]
# counts
# [10  9  9  9  9]
# counts
# [11 11 11 10 10]
# counts
# [11 11 11 11 10]
# counts
# [11 11 11 11 10]
# 100%|██████████| 9990/9990 [00:05<00:00, 1791.74it/s]
# df:
#              img_file  bbox_x1  bbox_y1  bbox_x2  bbox_y2  class  fold
# 0     train_00001.jpg        1       80      641      461    108     0
# 1     train_00002.jpg       57       53      293      236     71     0
# 2     train_00003.jpg       35       42      227      160     76     0
# 3     train_00004.jpg       10       21      254      165    188     0
# 4     train_00005.jpg        1       67      772      573     44     0
# ...               ...      ...      ...      ...      ...    ...   ...
# 9985  train_09986.jpg       61      206      996      621    122     3
# 9986  train_09987.jpg      127       45      665      412    176     1
# 9987  train_09988.jpg       23       13      231      112    151     3
# 9988  train_09989.jpg       24      103      561      387     59     4
# 9989  train_09990.jpg       52      122      750      429     44     4
#
# [9990 rows x 7 columns]
